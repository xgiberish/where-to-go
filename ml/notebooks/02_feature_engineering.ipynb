# %% [markdown]
# # 02 — Feature Engineering
# Encode categoricals, create interaction features, and save `data/processed/features_engineered.csv`.

# %%
import pandas as pd

df = pd.read_csv('../data/raw/destinations.csv', comment='#')
# TODO: add encoding and feature creation steps
df.head()

# %%
# Save engineered features
# df.to_csv('../data/processed/features_engineered.csv', index=False)
